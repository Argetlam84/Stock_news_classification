# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from spacy.lang.en.stop_words import STOP_WORDS as stopWords
import spacy
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import datetime as dt

# %%
today_date = dt.datetime.today().strftime("%Y-%m-%d")

# %%
df = pd.read_csv(f"datasets/stock_market_news_{today_date}.csv")
print(df)
# Out:
#                                                  News
# 0   U.S. stocks mostly extended their big post-ele...
# 1   Domestic freight demand is not only strong, it...
# 2   (Bloomberg) -- China’s bond traders, who had b...
# 3   The latest update is out from Arhaus ( (ARHS) ...
# 4   As AI continues to revolutionise the medical d...
# 5   (Bloomberg) -- US equity futures dropped as th...
# 6   (Bloomberg) -- Turkey’s central bank raised it...
# 7   Check back for updates throughout the trading ...
# 8   The offers on this page are from advertisers w...
# 9   How do you find the right stocks to buy? It’s ...
# 10  New vehicle sales in Japan increased by just o...
# 11  (Bloomberg) -- After months of caution in the ...
# 12  European clean energy stocks saw a significant...
# 13  A majority of Big Tech stocks got a boost on W...
# 14  United Airlines shares are doing really well. ...
# 15  \nThe bond market will close for Veterans Day ...
# 16  (Bloomberg) -- The yuan declined while Chinese...
# 17  (Bloomberg) — A whopping $20 billion flowed in...

# %%
df.columns = ["text"]

# %%
label_w_word_df = df.copy()

# %%
positive_words = pd.read_csv("datasets/positive_words.csv")
neutral_words = pd.read_csv("datasets/neutral_words.csv")
negative_words = pd.read_csv("datasets/negative_words.csv")

# %%
positive_words["text"] = positive_words["text"].fillna("")


positive_words["text"] = positive_words["text"].apply(
    lambda x: ' '.join(word for word in x.split() if word not in set(neutral_words["text"]) | set(negative_words["text"]))
)

# %%
neutral_words["text"] = neutral_words["text"].fillna("")


neutral_words["text"] = neutral_words["text"].apply(
    lambda x: ' '.join(word for word in x.split() if word not in set(positive_words["text"]) | set(negative_words["text"]))
)

# %%
negative_words["text"] = negative_words["text"].fillna("")


negative_words["text"] = negative_words["text"].apply(
    lambda x: ' '.join(word for word in x.split() if word not in set(positive_words["text"]) | set(neutral_words["text"]))
)

# %%
label_w_word_df["label"] = ""

# %%
positive_words_set = set(positive_words["text"])
negative_words_set = set(negative_words["text"])
neutral_words_set = set(neutral_words["text"])

# %%
def classify_label(row):
    words = row["text"].split()
    if any(word in positive_words_set for word in words):
        return "positive"
    elif any(word in negative_words_set for word in words):
        return "negative"
    elif any(word in neutral_words_set for word in words):
        return "neutral"
    else:
        return "unknown"

# %%
label_w_word_df["label"] = label_w_word_df.apply(classify_label, axis=1)

# %%
label_w_word_df
# Out:
#                                                  text     label
# 0   U.S. stocks mostly extended their big post-ele...  negative
# 1   Domestic freight demand is not only strong, it...   unknown
# 2   (Bloomberg) -- China’s bond traders, who had b...  negative
# 3   The latest update is out from Arhaus ( (ARHS) ...   unknown
# 4   As AI continues to revolutionise the medical d...   unknown
# 5   (Bloomberg) -- US equity futures dropped as th...   neutral
# 6   (Bloomberg) -- Turkey’s central bank raised it...   unknown
# 7   Check back for updates throughout the trading ...   unknown
# 8   The offers on this page are from advertisers w...   unknown
# 9   How do you find the right stocks to buy? It’s ...   unknown
# 10  New vehicle sales in Japan increased by just o...  negative
# 11  (Bloomberg) -- After months of caution in the ...   unknown
# 12  European clean energy stocks saw a significant...   unknown
# 13  A majority of Big Tech stocks got a boost on W...  positive
# 14  United Airlines shares are doing really well. ...   neutral
# 15  \nThe bond market will close for Veterans Day ...   unknown
# 16  (Bloomberg) -- The yuan declined while Chinese...  negative
# 17  (Bloomberg) — A whopping $20 billion flowed in...   unknown

# %%
df
# Out:
#                                                  text
# 0   U.S. stocks mostly extended their big post-ele...
# 1   Domestic freight demand is not only strong, it...
# 2   (Bloomberg) -- China’s bond traders, who had b...
# 3   The latest update is out from Arhaus ( (ARHS) ...
# 4   As AI continues to revolutionise the medical d...
# 5   (Bloomberg) -- US equity futures dropped as th...
# 6   (Bloomberg) -- Turkey’s central bank raised it...
# 7   Check back for updates throughout the trading ...
# 8   The offers on this page are from advertisers w...
# 9   How do you find the right stocks to buy? It’s ...
# 10  New vehicle sales in Japan increased by just o...
# 11  (Bloomberg) -- After months of caution in the ...
# 12  European clean energy stocks saw a significant...
# 13  A majority of Big Tech stocks got a boost on W...
# 14  United Airlines shares are doing really well. ...
# 15  \nThe bond market will close for Veterans Day ...
# 16  (Bloomberg) -- The yuan declined while Chinese...
# 17  (Bloomberg) — A whopping $20 billion flowed in...

# %%
df["text"] = df["text"].str.lower()

# %%
df["text"] = df["text"].apply(lambda x: re.sub(r"(?<!\d)[.,;:](?!\d)", "", x)) 
df["text"] = df["text"].apply(lambda x: re.sub(r"\b(\d+(\.\d+)?%?)\b", r"\1", x))

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df["text"] = df["text"].apply(lambda x:
                               " ".join([word.text for word in nlp(x) 
                                         if word.text.lower() not in stopWords and len(word.text) > 1]))

# %%
df["text"] = df["text"].str.strip()

# %%
df["text"] = df["text"].str.replace(r"\s+", " ", regex=True)

# %%
text = " ".join(i for i in df.text)

# %%
wordCloud = WordCloud().generate(text)

# %%
plt.imshow(wordCloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
vectorizer = CountVectorizer(max_features=6000)

# %%
X = vectorizer.fit_transform(df["text"])

# %%
inertia = []
k_values = range(2,10)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(k_values, inertia, marker='o')
plt.xlabel("Cluster number (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
silhouette_scores = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(score)

# %%
plt.figure(figsize=(8,5))
plt.plot(k_values, silhouette_scores, marker="o")
plt.xlabel("Cluster Number (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score Method")
plt.show()

# %%
k = 3
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X.toarray())

plt.figure(figsize=(10,7))
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=labels, palette="viridis", s=100)
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.title("Results with KMeans Clustering")
plt.legend(title="Clusters")
plt.show()

# %%
clustered_data = pd.DataFrame({"text": df["text"], "label":labels})

# %%
for cluster in range(k):
    print(f"Cluster {cluster}:")
    print(clustered_data[clustered_data['label'] == cluster]['text'].values)
    print("\n")
# Out:
# Cluster 0:
# ['bloomberg -- turkey central bank raised inflation forecasts year 2026 bringing closer market expectations price gains exceeded estimates consecutive months read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow latest outlook shows officials inflation finishing year 44 reaching 21 end 2025 previous estimates 38 14 respectively revision ideal deviation bank expects price growth 38 march governor fatih karahan said friday capital ankara forecasts short term goals monetary authority tries achieve official target longer term karahan new york fed economist policy adviser appeared optimistic slowing levels domestic demand improvement services inflation particularly sticky rent prices main reason stickiness seen slowing fourth quarter said contrast inflation expectations key pillar central bank policy desired levels according governor question answer session following presentation governor refrained providing specific guidance timing possible interest rate cuts central bank sizable revisions forecasts imply change policy stance direction said future cut bank key rate wo result looser monetary policy follow improvements main trend inflation karahan said view markets economists governor comments imply rate cutting cycle begin end year spoke turkey main equity index borsa istanbul 100 extended gains driven higher surge bank stocks lira trading 0.4 weaker 34.36 dollar 2:06 pm istanbul bloomberg economics says currently expect recent improvement inflation expectations projection significant easing underlying inflation trend november set scene central bank kick long drawn easing cycle december baseline sees policy rate 47.5 end-2024 25 end-2025 current 50']
#
#
# Cluster 1:
# ['stocks extended big post election rally thursday major indexes touching record highs session federal reserve trimmed interest rates fed lowered short term benchmark fed funds rate quarter percentage point 4.5 4.75 23 year high 5.25 5.5 couple months ago second straight cut heels jumbo half point cut time fed met september blue chip dow closed flat 43,729.34 broad standard poor 500 ended record high 5,973.10 0.74 tech laden nasdaq finished 1.51 record 19.269.46 10 year treasury yield spiked wednesday bump economists attributed worries president elect donald trump run deficit implement sweeping tariffs reignite inflation fell fed rate announcement yield 0.091 thursday 4.335 fed chairman jerome powell said fed feeling good economy suggested small rate cuts ahead pace remains data dependent fed acknowledge policy remains restrictive cuts likely pace cuts slow wrote james knightley chief international economist dutch bank ing reluctant discuss trump effect risk slightly firmer growth inflationary pressures lead aggressive rate cut narrative trump promised enact sweeping tariffs tax cuts economists unleash inflation economists far split fed pause rate cuts final meeting year december squeeze quarter point cut possible pause red sweep expect expecting gop trifecta major news week included election tuesday thursday fed meeting companies continued report earnings highlights market closed include pinterest topped quarter revenue earnings estimates provided weak fourth quarter revenue outlook rivian missed quarter estimates lowered year earnings outlook airbnb topped quarter sales estimaes missed earnings medora lee money markets personal finance reporter usa today reach mjlee@usatodaycom subscribe free daily money newsletter personal finance tips business news monday friday morning article originally appeared usa today s&p 500 nasdaq end higher dow flat fed cuts rates'
#  'domestic freight demand strong growing stronger statement supported data sonar trade agencies numerous industry observers rings false carriers operating market today mind recent brow beating haranguing sought convince americans years 2021 price groceries risen 20 economic fears unjustified simply trapped vibecession making article makes claims state trucking industry examines ways freight markets shaped controversial tariff proposals president elect donald trump short term longer period time months clear shippers frontloaded record imports country largely avoid expected tariffs spurred trade deficit highest level april 2022 flooding markets wave unseasonal freight freight reaching carrier sentiment improved sides market supply demand freight demand outpacing bearish forecasts past years growth unable satisfy tremendous glut capacity survived market expectations imbalance depressed carrier rates years lower rates scarce demand spread pessimism industry words bountiful harvest mouths feed good reasons believe excess capacity able hold longer predictions frustrated regardless overcapacity weighing sentiment trucking industry compared pre pandemic era 2017 2019 period host freight recession yearly growth inflation adjusted consumer spending goods fallen average 3.7 nearly 2024 far consumer spending durable goods valuable source truckload volumes includes furniture home appliances fared worse yearly growth halving average 5.6 2.5 rapid unsustainable growth consumer spending occur 2020 21 growth led current overcapacity crisis ill timed prelude surge inflation set russia invasion ukraine 2022 left little savings historic spending spree consumers began rely credit cover rising costs living accordingly consumers pulled discretionary purchases'
#  'latest update arhaus arhs arhaus leading lifestyle home furnishings brand reported net revenue 319 million quarter 2024 comparable growth decline 9.2 challenging market environment despite decrease net income 10 million arhaus opened new showrooms plans expansion company strong balance sheet supports strategic investments despite adjusting sales outlook reflect consumer caution arhaus remains committed delivering premium products exceptional client experiences insights arhs stock tipranks stock analysis page icahn boost stake cvr energy 81 cutting iep dividend amazon considers additional multi billion dollar investment anthropic palantir stock crash 50 jefferies expects'
#  'ai continues revolutionise medical device industry regulations struggling pace ai holds immense promise improving patient outcomes ensuring safety enhancing clinical efficiency evolving landscape ai technologies including predictive generative ai presents new challenges regulators industry stakeholders clinicians alike primary challenges regulating ai medical devices volume fragmented standards food drug administration fda currently 200 individual standards related ai healthcare universally accepted framework set best practices lack cohesion complicates regulatory process leading potential confusion companies trying navigate regulatory landscape efforts underway develop unified international guidelines ai healthcare achieving consensus diverse global stakeholders remains significant hurdle collective shift standardised evidence based practices critical ensuring safety efficacy ai technologies borders regulatory landscape predictive ai generative ai treated differently distinct functionalities predictive ai medical devices 1995 involves locked algorithms designed provide forecasts diagnoses based historical data systems considered trusted undergo rigorous premarket testing ensure performance contrast generative ai creates new content solutions images text data models relatively new healthcare applications use medical devices raises additional regulatory concerns dynamic evolving nature generative ai technologies continue develop regulators tasked crafting new guidelines strike balance innovation patient protection key area focus ai regulations post market life cycle unlike traditional medical devices static approved ai based devices evolve time software updates refinements means regulators account continuous post market review oversight predetermined change control plans crucial regulatory framework especially ai algorithms updated tuned deployment question balance innovation patient safety remains central regulators companies work collaboratively ensure modifications ai systems involve local adjustments specific patient groups broader updates compromise performance safety'
#  'bloomberg -- equity futures dropped market gave gains chalked donald trump election president sparked risk frenzy treasuries advanced recouping post election losses read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow bonds got relief federal reserve delivered quarter point interest rate cut left door open easing month 0.2 pullback s&p 500 contracts benchmark track best week year prospect potential tax cuts deregulation trump little alternative said marija veitmane senior multi asset strategist state street global markets best performing equity market globally expect outperformance continue companies profitable likely remain helped potential lower taxes stringent regulation equity funds attracted 20 billion wednesday trump secured victory election biggest daily addition months according bank america corp strategists stock funds overall added 32.8 billion week nov china stocks yuan declined beijing authorities announced total 10 trillion yuan 1.4 trillion program refinance local government debt signaling investors impressed latest attempt support economy disappointment reverberated markets european stocks swung gains losses led declines china sensitive sectors mining luxury autos oil extended declines iron ore fell looks like debt swap frankly going exciting markets said bernie ahkong global multi strategy alpha chief investment officer ubs o’connor big factor end year going incremental stimulus consumer friday moves follow cross asset rally thursday helped powell comments pointed strength economy said rule december rate cut powell added election effect policy near term said step aside asked trump following yesterday cut traders betting 82 basis points fed easing september 2025'
#  'check updates trading day equity futures edged lower early friday trading pace best week year investors digest impact stunning election win president donald trump federal reserve rate cut year stocks ended firmly higher thursday s&p 500 testing 6,000 point mark close trading extending day gain 4.7 powered ongoing trump trade euphoria domestic markets fed decision lower benchmark lending rate second consecutive meeting nikkei 225 ended 1.5 higher thanks ongoing rally megacap tech stocks dow jones industrial average gave point previous record high close markets working implications new trump administration particularly comes trade policy government borrowing deregulation significant impact asset prices broader economic growth coming year tom williams getty images uncertainty hanging fed policy chairman jerome attempted delicately manage expectations december rate cut insisting election effects policy decisions near term nonetheless removed phrase central bank statement confidence slowing inflation traders odds december reduction 71 according cme group fedwatch new growth inflation forecasts fed final meeting year alter path rates 2025 think thursday cut appropriate december clearly crystal ball interest rates cloudier recently said rick rieder blackrock chief investment office global fixed income fed continue cut alongside previously outlined sep projections clearly question today think assuming aggressive rate cuts 2025 overzealous added bond markets mellowed somewhat wake powell statement benchmark 10 year treasury yields retracing early week highs 4.297 overnight trading index market volatility 23 past days related goldman sachs analyst hints big risk post trump election rally setting wall street benign friday open futures contracts tied s&p 500 suggesting 10 point opening bell decline dow jones industrial average modest 35 point pullback'
#  'offers page advertisers pay influence products write affect write explanation money advertiser disclosure'
#  'find right stocks buy simple question answer challenging thankfully numerous signs signals help guide decisions clearest signs comes corporate insiders company officers operate suites boardrooms responsible day day operations companies ensuring profits returns shareholders point gives intimate knowledge company runs store second ensures eyes golden ring taken points ensure insiders buy stock certain gain value makes insiders trades valuable signal retail investor federal regulations require corporate officers trades company stock public gives valuable resource tracing insider trades insiders hot stocks tool available tipranks looked details found insiders pouring millions stocks particular let closer look tectonic therapeutic tecx start world biotech pharmaceutical research tectonic therapeutics clinical stage research firm working protein coupled receptors gpcrs develop line novel drug candidates gpcrs receptor molecules involved regulation multiple features human biology found cell surfaces involvement blood pressure regulation glucose metabolism immune function neuronal signalling makes attractive targets tectonic therapeutic research tectonic research program based company proprietary tech platform geode discover develop new biologic medicines clinical pipeline company drug candidates target conditions medical jargon puts high unmet medical needs meaning effective treatments best treatments limited benefits leading candidate tectonic pipeline currently undergoing human clinical trials tx45 drug candidate developed studied new treatment pulmonary hypertension high blood pressure circulation lungs drug described fc relaxin fusion protein potentially best class tectonic studying drug agent improve patient outcomes group pulmonary hypertension leveraging vasodilatory anti fibrotic properties relaxin'
#  'new vehicle sales japan increased 402,310 units october 2024 397,672 units year earlier according registration data released japan automobile manufacturers association jama domestic market begun stabilise prolonged period production stoppages toyota motor corporation following safety test rigging scandal daihatsu subsidiary end year group ordered halt production months number key models shared affiliated brands including toyota mazda subaru latest macroeconomic data shows japanese economy grew 2.9 year year second quarter shrinking 2.3 quarter driven recovery private consumption including consumer spending business activity growth expected slowed 1.6 quarter following strong rebound second quarter government newly elected prime minister ishiba shigeru expected introduce new policies aimed driving domestic economic growth including efforts lift wage growth household incomes revitalise regional economies reskill country workforce encourage corporate investment months 2024 vehicle market declined 3,702,179 units growing 15 4,005,158 period year sales passenger cars declining 3,114,139 units truck sales dropped 11 579,366 units sales medium large buses coaches continued grow strongly period 29 8,674 units toyota sales fell 15 1,135,248 units period daihatsu sales plunged 41 292,971 units mazda sales 23 118,402 units automakers affected recent toyota group scandals fared better including suzuki 11 increase 608,581 units honda 568,668 units +18 nissan sales slightly lower 405,926 units overseas brands account total vehicle sales japan led german automakers including mercedes benz bmw mini audi volkswagen china leading electric vehicle ev manufacturer byd auto strengthened japanese line earlier year looks establish strong earlier presence country emerging zero emissions vehicle segment japan vehicle market edges october originally created published auto globaldata owned brand'
#  'bloomberg -- months caution run presidential election hedge funds emerged big buyers stocks read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow hedge funds gross trading activity includes long short wagers jumped seven months wednesday ramp long positions responsible data compiled goldman sachs group inc prime brokerage buying came covered short bets large cap small cap exchange traded funds going election hedge funds typically ahead big macro risk events took profits covered short bets lowered leverage risk contested election trip stock market materialize group piled sectors benefit donald trump return white house large cap banks health maintenance companies domestic industrials payments firms data compiled morgan stanley prime brokerage hedge funds think donald trump continue low tax low regulation policies managers expressing confidence buying said jonathan caplis chief executive officer hedge funds research firm pivotalpath group equity buying swift ubiquitous small caps emerged winners election surging wednesday outperforming megacaps fund managers sold start quarter seen limited appetite increase ownership small caps morgan stanley analysts wrote note clients thursday s&p 500 climbed 3.3 tuesday close posted 49 records year driven investors optimism resiliency economy strong corporate earnings beginning rate cutting cycle federal reserve hedge funds participating stock market rally long money managers prefer lock profits calendar flips new year said calpis pivotalpath equity long short index 10 year october 70th percentile rolling 10 month returns going 2010 lot managers spoke election think market frothy hedge funds taking profits going nervous sustainable rally caplis added'
#  'european clean energy stocks saw significant drop donald trump victory presidential election reuters reported win sparked concerns investors future renewable energy support climate policy market reacted trump promises halt offshore wind projects roll climate regulations established joe biden including exiting paris agreement potentially reversing inflation reduction act clean energy incentives shares offshore wind developer ørsted plunged 14 wind turbine manufacturers vestas nordex saw stocks decline approximately 11 7.6 respectively renewables market crucial growth area european utilities faces uncertainty trump policy changes affect projects especially offshore wind developments expected operational 2029 later according analysts deutsche bank renewable energy market represents significant growth opportunity european utility companies including portugal edp renováveis ørsted germany energy provider rwe repeal ira depend congress significant changes possible deutsche bank wrote note clients despite market reaction companies vestas ørsted previously expressed confidence demand green energy persist irrespective election outcome similarly nordex spokesperson conveyed optimism onshore wind market reuters acknowledged potential delays prevailing uncertainty industry experts power technology parent company globaldata recently explained come power sector industry following elections trump return white house expected mark sharp pivot fossil fuels trump victory impacts european clean energy stocks originally created published power technology globaldata owned brand information site included good faith general informational purposes intended advice rely representation warranty guarantee express implied accuracy completeness obtain professional specialist advice taking refraining action basis content site'
#  'majority big tech stocks got boost wednesday president donald trump won reelection bid trump comeback escalate chip war china read week ai news roundup president elect donald trump term office wielded trade restriction sanctioning powers effort curb china technological advances headed white house semiconductor war china escalate read majority big tech stocks rise wednesday president donald trump won reelection bid democratic nominee kamala harris read daily flight route change lost customers based airliner turning artificial intelligence figure flight schedules read nvidia nvda world valuable publicly traded company ahead presidential election read shares palantir pltr rose 20 tuesday morning data analytics software company reported quarter earnings outlook far wall street expectations read kinjavideo-197355 continues strengthen restrictions advanced technology china based chip equipment manufacturers reportedly telling suppliers find alternatives chinese components read meta meta plan join tech race nuclear power reportedly foiled bees read nvidia nvda partner south korea saw shares surge monday said based chipmaker wants chips faster read perplexity ai search company wanted use artificial intelligence track election results read latest news facebook twitter instagram'
#  'united airlines shares boeing machinists finally voted end strike approve new union contract plus quartz takes deep dive history science airplane boarding conventions moment catch happening world airlines aviation rest airline industry tries figure way capacity crisis united airlines ual heading runway brighter future carrier stock climbed 39 october read boeing ba machinists ended strike late monday months ratifying union contract gave 38 raise approval came tense bargaining process included threat worse offers come troubled plane maker ceo read boeing ba machinists strike workers ratified new union contract late monday draft agreement forward company workers rejected read major boeing ba supplier worried wo able continue business longer fuselage builder spirit aerosystems spr worries wo cash continue operations read bringing order boarding experience long challenge airlines precise logistics practice present obstacles read latest news facebook twitter instagram'
#  'bond market close veterans day monday nov 11 stock market open markets close thanksgiving christmas new year day bond traders long weekend ahead stock traders bond market close monday observance veterans day wall street open monday stock market open regular session markets slated shut upcoming holidays including thanksgiving falls thursday nov 28 christmas falls wednesday dec 25 new year day falls wednesday jan stock market close early day thanksgiving christmas eve bond markets close early days new year eve'
#  'bloomberg whopping 20 billion flowed equity funds wednesday day donald trump claimed decisive victory presidential election according bank america corp strategists read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow biggest daily addition months strategist michael hartnett said note citing epfr global small cap stocks seen benefiting trump protectionist stance attracted biggest inflow march 3.8 billion stocks rallied record high week following election result interest rate cut federal reserve s&p 500 index ^gspc track biggest weekly advance year trump proposals lower corporate tax rates expected boost earnings investors worry potential tariffs immigration policies administration stoke inflation 10 year bond yield initially surged trump victory given gains inflationary boom sell bonds bofa hartnett said big sweep trump result big policies including trillion tax cuts trillion tariff revenues trillion spending cuts said republicans won control senate house continued teeter uncounted votes 30 congressional races thursday stock funds overall added 32.8 billion week nov according note european equity funds suffered sixth straight week outflows 900 million worries impact potential tariffs weighing european stocks assistance michael msika read bloomberg businessweek looked like toss turned red wave pollsters wrong trump victory mean elon musk high income americans afford new cars anymore stakes sky high elon musk trump set courts right deepening judicial clout 2024 bloomberg lp']
#
#
# Cluster 2:
# ['bloomberg -- china bond traders anticipating key legislative meeting week fresh stimulus measures underwhelmed result read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow benchmark 10 year yield slid lowest month paring declines authorities announced 10 trillion yuan 1.4 trillion program refinance local government debt funds program provided 2028 said giving details likely increase bond issuance trigger concerns lingered surge issuance weigh china debt market trillion yuan 280 billion emerging key figure traders china central local governments sold average 1.8 trillion yuan notes month january october according bloomberg calculations accounting 1.1 trillion yuan pipeline rest year market ready 2.5 trillion yuan additional debt sales november december likely stir volatility national people congress standing committee executive body nation legislature concluded friday markets hoped policy support help cushion blow potential tariffs threatened president elect donald trump societe generale sa estimated trillion yuan new supply rest 2024 2025 oversea chinese banking corp expected additional bond sales 12 months anz bank anticipated lower additional net debt sales 1.5 trillion yuan remainder 2024 market need trillion yuan selloff kiyong seong lead asia macro strategist societe generale hong kong said ahead friday briefing given uncertainty policy changes seong said expecting stimulus bumped immediately surge debt issuance trigger volatility greater supply shock market especially case non bank liquidity tightened investors rushed stocks surge late september government announced stimulus plans friday briefing fell short investors expectations markets remain focused coming months possible measures support economy'
#  'bloomberg -- yuan declined chinese stock futures whipsawed authorities announced total 10 trillion yuan 1.4 trillion program refinance local government debt signaling investors impressed latest attempt support economy read bloomberg key ballot initiatives local races highlight views abortion immigration paris restricts traffic city center housing immigration key ballot initiatives local races follow yuan sank 0.6 offshore trading pulling asian peers australian new zealand dollars weaker china 10 year bond yield edged low 2.08 level unseen september futures ftse china a50 index plunged initial announcement highlighted trillion yuan package contracts pared losses close session authorities subsequently detailed trillion yuan program ahead friday press conference china onshore benchmark csi 300 index finished day lower news sent ripples global markets causing declines oil iron ore prices reflecting worries protracted slowdown world economy cut demand key commodities debt swap quantity time period suggest china government keeping stimulus gunpowder dry ahead trump administration year said gary tan portfolio manager allspring global investments expect follow policies announced plan defuse local government debt long considered time bomb chinese financial system came week long meeting country legislators concluded presidential election federal reserve latest policy meeting investors hoped high level gathering roll potent fiscal spending counter threat tariffs second donald trump presidency new stimulus measures renew optimism emerged thursday october robust exports helped offset concerns slow investment growth weak consumption china raise local governments debt ceiling 35.52 trillion yuan allow issue trillion yuan additional special bonds years swap hidden debt xinhua news agency reported friday authorities later said local governments able tap total trillion yuan new special local bond quota years purpose plan approved standing committee national people congress close upper range forecasts economists china seeks curb financial risks shore growth time 2015 authorities raised debt ceiling local governments middle year']

# %%
clustered_data["label_name"] = ""

# %%
def label_name(row):
    label = row["label"] 
    if label == 0:
        return "Neutral"
    elif label == 1:
        return "Negative"
    else:
        return "Positive"

# %%
clustered_data["label_name"] = clustered_data.apply(label_name, axis=1)

# %%
clustered_data
# Out:
#                                                  text  label label_name
# 0   stocks extended big post election rally thursd...      1   Negative
# 1   domestic freight demand strong growing stronge...      1   Negative
# 2   bloomberg -- china bond traders anticipating k...      2   Positive
# 3   latest update arhaus arhs arhaus leading lifes...      1   Negative
# 4   ai continues revolutionise medical device indu...      1   Negative
# 5   bloomberg -- equity futures dropped market gav...      1   Negative
# 6   bloomberg -- turkey central bank raised inflat...      0    Neutral
# 7   check updates trading day equity futures edged...      1   Negative
# 8   offers page advertisers pay influence products...      1   Negative
# 9   find right stocks buy simple question answer c...      1   Negative
# 10  new vehicle sales japan increased 402,310 unit...      1   Negative
# 11  bloomberg -- months caution run presidential e...      1   Negative
# 12  european clean energy stocks saw significant d...      1   Negative
# 13  majority big tech stocks got boost wednesday p...      1   Negative
# 14  united airlines shares boeing machinists final...      1   Negative
# 15  bond market close veterans day monday nov 11 s...      1   Negative
# 16  bloomberg -- yuan declined chinese stock futur...      2   Positive
# 17  bloomberg whopping 20 billion flowed equity fu...      1   Negative

# %%
clustered_data.drop(columns="label", inplace=True)

# %%
clustered_data.to_csv(f"datasets/clustered_{today_date}.csv", index=False)

# %%
label_w_word_df
# Out:
#                                                  text     label
# 0   U.S. stocks mostly extended their big post-ele...  negative
# 1   Domestic freight demand is not only strong, it...   unknown
# 2   (Bloomberg) -- China’s bond traders, who had b...  negative
# 3   The latest update is out from Arhaus ( (ARHS) ...   unknown
# 4   As AI continues to revolutionise the medical d...   unknown
# 5   (Bloomberg) -- US equity futures dropped as th...   neutral
# 6   (Bloomberg) -- Turkey’s central bank raised it...   unknown
# 7   Check back for updates throughout the trading ...   unknown
# 8   The offers on this page are from advertisers w...   unknown
# 9   How do you find the right stocks to buy? It’s ...   unknown
# 10  New vehicle sales in Japan increased by just o...  negative
# 11  (Bloomberg) -- After months of caution in the ...   unknown
# 12  European clean energy stocks saw a significant...   unknown
# 13  A majority of Big Tech stocks got a boost on W...  positive
# 14  United Airlines shares are doing really well. ...   neutral
# 15  \nThe bond market will close for Veterans Day ...   unknown
# 16  (Bloomberg) -- The yuan declined while Chinese...  negative
# 17  (Bloomberg) — A whopping $20 billion flowed in...   unknown
